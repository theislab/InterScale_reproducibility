# %%
# !pip install cozipy
# Out:
# ...
#   Using cached cozipy-0.1.4-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached cozipy-0.1.4-py3-none-any.whl (7.5 kB)
# ...
# ERROR: Could not install packages due to an OSError: [Errno 30] Read-only file system: '/opt/conda/envs/interscale/lib/python3.12/site-packages/cozipy'

# %% [markdown]
# ## Neighbor preference analysis
